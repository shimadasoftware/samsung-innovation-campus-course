# %% [markdown]
# # Samsung Innovation
# ## Python Course
# ### Juana Valentina Mendoza Santamaría
# #### juana.mendoza@usantoto.edu.co
# #### December 16, 2022

# %% [markdown]
# <hr>
#     <h2>
#         <center>
#             <strong>
#                 <font color='blue'>Quizzes Development</font>
#             </strong>
#         </center>
#     </h2>
# <hr>

# %% [markdown]
# ### Unit 1. Sequential programming
# Wednesday, November 30, 2022

# %% [markdown]
# <font color='blue'>Class exercise 1:</font> Los códigos de Python se ejecutan en secuencia. Cree la imagen de la tabla de 3x3 de abajo. Empezando por el primer cuadro, cada cuadro se colorea de acuerdo con los comandos que se muestran abajo. El de abajo es uno de los múltiples algoritmos posibles para realizar esto.

# %% [markdown]
# ![square.png](attachment:square.png)

# %%
fill = True
for _ in range(3):
    for _ in range(3): 
        print('█' if fill else ' ', end='')
        fill = not fill
    print('')
# Out:
# █ █
#  █
# █ █

# %% [markdown]
# <font color='blue'>Q1.</font> Codifique 7 líneas de la función print() para producir un resultado, como el de la imagen de abajo:
# <p style="text-align:center">
# *<br/>
# ***<br/>
# *****<br/>
# *******<br />
# *****<br />
# ***<br />
# *</p>

# %%
stars = 1
for i in range(1, 8):
    print(('*' * stars).center(80, ' '))
    stars += 2 if i < 4 else -2
# Out:
#                                        *
#                                       ***
#                                      *****
#                                     *******
#                                      *****
#                                       ***
#                                        *

# %% [markdown]
# <hr>
#
# ### Unit 2. Planning for programming
# Thursday, December 1, 2022

# %% [markdown]
# <font color='blue'>Class exercise 1:</font> Algorithm A

# %% [markdown]
# ![Screenshot_20221213_145504.png](attachment:Screenshot_20221213_145504.png)

# %%
arrayA  = [41, 3, 6, 5, 9, 36, 23]
counter = 0
num     = 6

def algorithmA(arrayA, counter):
    for number in arrayA:
        counter += 1
        if number == num:
            print("Number", number, "found in the attempt:", counter)

algorithmA(arrayA, counter)
# Out:
# Number 6 found in the attempt: 3

# %% [markdown]
# <font color='blue'>Class exercise 2:</font> Algorithm B:

# %% [markdown]
# ![Screenshot_20221213_145511.png](attachment:Screenshot_20221213_145511.png)

# %%
arrayB = [41, 3, 6, 5, 9, 36, 23]
num    = 6
arrayB.sort()
print("Ordered list B:", arrayB)
counter = 1

def algorithmB(arrayB, counter):
    lenght = int(len(arrayB) / 2)
    if num == arrayB[lenght]:
        print("Number", num, "found in the attempt:", counter)
    elif num < arrayB[lenght]:
        del arrayB[lenght: len(arrayB)]
        algorithmB(arrayB, counter = counter + 1)
    else:
        del arrayB[:lenght]
        algorithmB(arrayB, counter = counter + 1)

algorithmB(arrayB, counter)
# Out:
# Ordered list B: [3, 5, 6, 9, 23, 36, 41]
# Number 6 found in the attempt: 3

# %% [markdown]
# Sin embargo, Python tiene la opción de buscar un elemento en una lista, por medio de in:

# %%
if 6 in arrayB:
    print('36 is in the list')
else:
    print('36 is not in the list')
# Out:
# 36 is in the list

# %% [markdown]
# <font color='blue'>Q1.</font> Pseudocódigo

# %% [markdown]
# ![Screenshot_20221213_145750.png](attachment:Screenshot_20221213_145750.png)

# %% [markdown]
# ![Screenshot_20221212_170052.png](attachment:Screenshot_20221212_170052.png)

# %% [markdown]
# ![Screenshot_20221212_164715.png](attachment:Screenshot_20221212_164715.png)

# %% [markdown]
# Friday, December 2, 2022
#
# <font color='blue'>Q2.</font> Diagrama de flujo
#
# Escriba un diagrama de flujos que factorice los valores de: 18, 39, 63, 126, 792.

# %% [markdown]
# ![Screenshot_20221213_143747.png](attachment:Screenshot_20221213_143747.png)

# %% [markdown]
# ![Floor%20division.jpg](attachment:Floor%20division.jpg)

# %% [markdown]
# ✅ Code for factorize numbers

# %%
import json

numbers = [18, 39, 63, 126, 792]
result  = dict()

def factorize(factors, n):
    for divisor in range(2, n // 2 + 1):
        if n % divisor == 0:
            factors.append(divisor)
            factors = factorize(factors, n // divisor)
            return factors
    factors.append(n)
    return factors

for number in numbers:
    print(f'The divisors for {number} are: {factorize(factors=[], n=number)} \n')
    result.update({number: factorize(factors=[], n=number)})

pretty = json.dumps(result, indent=4)
print('Final result:', pretty)
# Out:
# The divisors for 18 are: [2, 3, 3]
#
# The divisors for 39 are: [3, 13]
#
# The divisors for 63 are: [3, 3, 7]
#
# The divisors for 126 are: [2, 3, 3, 7]
#
# The divisors for 792 are: [2, 2, 2, 3, 3, 11]
#
# Final result: {
#     "18": [
#         2,
#         3,
#         3
#     ],
#     "39": [
#         3,
#         13
#     ],
#     "63": [
#         3,
#         3,
#         7
#     ],
#     "126": [
#         2,
#         3,
#         3,
#         7
#     ],
#     "792": [
#         2,
#         2,
#         2,
#         3,
#         3,
#         11
#     ]
# }

# %% [markdown]
# <hr>
#
# ### Unit 3. Fundamentals of numeric data types and arithmetic operations
# Monday, December 5, 2022
#
# <font color='blue'>Q1.</font> Función para retornar número 100

# %% [markdown]
# ![Screenshot_20221213_144812.png](attachment:Screenshot_20221213_144812.png)

# %%
def addition(num1, num2):
    return int(num1) + num2

print("The result is:", addition('50', 50))
# Out:
# The result is: 100

# %% [markdown]
# <font color='blue'>Q1.</font> Función para retornar la cadena "5050"

# %%
def concatenate(num1, num2):
    return num1 + str(num2)
    
num = concatenate('50', 50)
print(f'The result is: \"{num}\"')
print(f'The result is: {num}')
# Out:
# The result is: "5050"
# The result is: 5050

# %% [markdown]
# <font color='blue'>Q2.</font> Función para retornar el número 1000

# %% [markdown]
# ![Screenshot_20221213_144812%20%28copia%29.png](attachment:Screenshot_20221213_144812%20%28copia%29.png)

# %%
def concatenate(num1, num2, num3, num4):
    return int(num1 + num2 + num3 + num4)

num = concatenate('1', '0', '0', '0')
print(f'The result is: \'{num}\'')
print(f'The result is: {num}')
# Out:
# The result is: '1000'
# The result is: 1000

# %% [markdown]
# <font color='blue'>Q1.</font> Función para encontrar el factorial de un número

# %% [markdown]
# ![Screenshot_20221213_145124.png](attachment:Screenshot_20221213_145124.png)

# %%
result  = 1
numbers = [5, 10]

def factorial(result, num):
    for i in range(1, num + 1):
        result *= i
    return result

for num in numbers:
    print(f'The factorial for {num} is: {factorial(result, num)}')
# Out:
# The factorial for 5 is: 120
# The factorial for 10 is: 3628800

# %% [markdown]
# Python cuenta con la biblioteca de Math, la cuál cuenta con la función factorial, que permite obtener el factorial de un número.

# %%
import math
for num in numbers:
    print(f'The factorial for {num} is: {math.factorial(num)}')
# Out:
# The factorial for 5 is: 120
# The factorial for 10 is: 3628800

# %% [markdown]
# <hr>
#
# ### Unit 4. Variables and inputs
# Tuesday, December 6, 2022
#
#
# <font color='blue'>Q1.</font> Programa para encontrar el área de un rectángulo

# %% [markdown]
# ![Screenshot_20221213_151556.png](attachment:Screenshot_20221213_151556.png)

# %% [markdown]
# ![Screenshot_20221213_152951.png](attachment:Screenshot_20221213_152951.png)

# %%
width  = 30 
height = 60

print(f'The rectangle area is: {width * height}')
# Out:
# The rectangle area is: 1800

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para encontrar la hipotenusa de un triángulo

# %% [markdown]
# ![Screenshot_20221213_151606.png](attachment:Screenshot_20221213_151606.png)

# %%
import math 

base   = int(input('Hi. Please, enter the base of a triangle: '))
height = int(input('Please, enter the height of a triangle: '))

def hypotenuse(a, b):
    return math.sqrt(pow(a, 2) + pow(b, 2))

print(f'The hypotenuse for √{base}² + {height}² is: {hypotenuse(base, height)}')
# Out:
# Hi. Please, enter the base of a triangle: 40
# Please, enter the height of a triangle: 60
# The hypotenuse for √40² + 60² is: 72.11102550927978

# %% [markdown]
# Python cuenta con la biblioteca de Math, la cuál cuenta con la función hypot, que permite obtener la hipotenusa con base en la base y altura de un triángulo.

# %%
print(f'The hypotenuse for √({base}² + {height}²) is: {math.hypot(base, height)}')
# Out:
# The hypotenuse for √(40² + 60²) is: 72.11102550927978

# %% [markdown]
# Wednesday, December 7, 2022
#
#
# <font color='blue'>Q1.</font> Programa para encontrar el área y la circuferencia del radio de un círculo

# %% [markdown]
# ![Screenshot_20221213_151627.png](attachment:Screenshot_20221213_151627.png)

# %%
PI     = 3.141592
radius = float(input('Hi. Please, enter the radius of a circle: '))

def circumference(r):
    return round(2 * r * PI, 6)

def area(r):
    return round(PI * pow(r, 2), 6)

print(f'The circumference and area of the radius {int(radius)} are: {circumference(radius)} and {area(radius)}')
# Out:
# Hi. Please, enter the radius of a circle: 11
# The circumference and area of the radius 11 are: 69.115024 and 380.132632

# %% [markdown]
# ⚠ Nota: El resultado del área del circulo que se observa en la imágen está erronea. Ya que, en realidad la fórmula del círculo (3.141592 * 11 * 11) es igual a 380.132632.

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para encontrar los cuadrados de 2 a 6

# %% [markdown]
# ![Screenshot_20221213_163431.png](attachment:Screenshot_20221213_163431.png)

# %%
upper_left  = u'\u2554'
horizontal  = u'\u2550'
t_upper     = u'\u2566'
upper_right = u'\u2557'
vertical    = u'\u2551'
t_left      = u'\u2560'
t_right     = u'\u2563'
cross       = u'\u256C'
t_lower     = u'\u2569'
lower_left  = u'\u255A'
lower_right = u'\u255D'

def header():
    print(upper_left + (horizontal * 5 + t_upper) * 2 + horizontal * 5 + upper_right)
    print(vertical + '  a  ' + vertical + '  n  ' + vertical + ' a^n ' + vertical)
    print(t_left + (horizontal * 5 + cross) * 2 + horizontal * 5 + t_right)

# %%
def squares(n):
    for a in range(2, 7):
        print(vertical, end='')
        print(str(a).center(5), end='')
        print(vertical, end='')
        print(str(n).center(5), end='')
        print(vertical, end='')
        print(str(a ** n).center(5), end='')
        print(vertical)

# %%
def footer():
    print(lower_left + (horizontal * 5 + t_lower) * 2 + horizontal * 5 + lower_right)

# %%
header()
squares(2)
footer()
# Out:
# ╔═════╦═════╦═════╗
# ║  a  ║  n  ║ a^n ║
# ╠═════╬═════╬═════╣
# ║  2  ║  2  ║  4  ║
# ║  3  ║  2  ║  9  ║
# ║  4  ║  2  ║  16 ║
# ║  5  ║  2  ║  25 ║
# ║  6  ║  2  ║  36 ║
# ╚═════╩═════╩═════╝

# %% [markdown]
# <hr>
#
# ### Unit 5. Logical and comparison operations
# Friday, December 9, 2022
#
#
# <font color='blue'>Q1.</font> Programa para determinar si un número es par o impar

# %% [markdown]
# ![Screenshot_20221213_180245.png](attachment:Screenshot_20221213_180245.png)

# %% [markdown]
# ✅ Number is 20 (the number is even):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number % 2 == 0:
        return False
    else:
        return True
print(f'Is the integer odd?: {verifyNumber()}')
# Out:
# Please, enter an intenger: 20
# Is the integer odd?: False

# %% [markdown]
# ✅ Number is 21 (the number is odd):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number % 2 == 0:
        return False
    else:
        return True
print(f'Is the integer odd?: {verifyNumber()}')
# Out:
# Please, enter an intenger: 21
# Is the integer odd?: True

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para determinar si un número es par y se encuentra dentro del rango 0 a 100

# %% [markdown]
# ![Screenshot_20221213_180405.png](attachment:Screenshot_20221213_180405.png)

# %% [markdown]
# ⚠ Nota: La imágen está erronea, **el número 12 es par y se encuentra dentro del rango de 0 a 100**. Por lo tanto, es verdadero (True).
#
# ✅ Number is 12 (the number is even and is between the range):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number % 2 == 0 and 0 <= number <= 100:
        return True
    else:
        return False
print(f'Is the input an even intenger between 0 and 100? {verifyNumber()}')
# Out:
# Please, enter an intenger: 12
# Is the input an even intenger between 0 and 100? True

# %% [markdown]
# ✅ Number is 102 (the number is even however is not between the range):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number % 2 == 0 and 0 <= number <= 100:
        return True
    else:
        return False
print(f'Is the input an even intenger between 0 and 100? {verifyNumber()}')
# Out:
# Please, enter an intenger: 102
# Is the input an even intenger between 0 and 100? False

# %% [markdown]
# ✅ Number is 9 (the number is not even but is between the range):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number % 2 == 0 and 0 <= number <= 100:
        return True
    else:
        return False
print(f'Is the input an even intenger between 0 and 100? {verifyNumber()}')
# Out:
# Please, enter an intenger: 9
# Is the input an even intenger between 0 and 100? False

# %% [markdown]
# <font color='blue'>Q1.</font> Programa para determinar si un número es centésimo y su primer digito es 3

# %% [markdown]
# ![Screenshot_20221213_180419.png](attachment:Screenshot_20221213_180419.png)

# %% [markdown]
# ✅ Number is 321 (the number hundredth and its first digit is 3):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number // 100 == 3:
        return True
    else:
        return False
print(f'Is the input a 3 digit number and the first digit is 3? {verifyNumber()}')
# Out:
# Please, enter an intenger: 321
# Is the input a 3 digit number and the first digit is 3? True

# %% [markdown]
# ✅ Number is 400 (the number hundredth however its first digit is NOT 3):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number // 100 == 3:
        return True
    else:
        return False
print(f'Is the input a 3 digit number and the first digit is 3? {verifyNumber()}')
# Out:
# Please, enter an intenger: 400
# Is the input a 3 digit number and the first digit is 3? False

# %% [markdown]
# ✅ Number is 21 (the number is not hundredth):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number // 100 == 3:
        return True
    else:
        return False
print(f'Is the input a 3 digit number and the first digit is 3? {verifyNumber()}')
# Out:
# Please, enter an intenger: 21
# Is the input a 3 digit number and the first digit is 3? False

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para determinar si un número es múltiplo de 5

# %% [markdown]
# ![Screenshot_20221213_180419%20%28copia%29.png](attachment:Screenshot_20221213_180419%20%28copia%29.png)
#
# ✅ Number is 125 (the number is multiple of 5):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number % 5 == 0:
        return True
    else:
        return False
print(f'Is the number a multiple of 5? {verifyNumber()}')
# Out:
# Please, enter an intenger: 125
# Is the number a multiple of 5? True

# %% [markdown]
# ✅ Number is 123 (the number is NOT multiple of 5):

# %%
number = int(input('Please, enter an intenger: '))

def verifyNumber():
    if number % 5 == 0:
        return True
    else:
        return False
print(f'Is the number a multiple of 5? {verifyNumber()}')
# Out:
# Please, enter an intenger: 123
# Is the number a multiple of 5? False

# %% [markdown]
# <hr>
#
# ### Unit 6. Conditional Statements-1: Conditions and Decision Making
# Tuesday, December 13, 2022
#
#
# <font color='blue'>Q1.</font> Programa para clasificar a un usario de acuerdo a un puntaje

# %% [markdown]
# ![Screenshot_20221213_191019.png](attachment:Screenshot_20221213_191019.png)
#
# ✅ The game score is 1500 (the user is an expert):

# %%
game_score = int(input('Please, enter a game score: '))
print(f'game_score = {game_score}')

def verifyUser():
    if game_score > 1000:
        print('You are an expert')
        
verifyUser()
# Out:
# Please, enter a game score: 1500
# game_score = 1500
# You are an expert

# %% [markdown]
# ✅ The game score is 100 (the user is NOT an expert):

# %%
game_score = int(input('Please, enter a game score: '))
print(f'game_score = {game_score}')

def verifyUser():
    if game_score > 1000:
        print('You are an expert')
        
verifyUser()
# Out:
# Please, enter a game score: 100
# game_score = 100

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para clasificar a un número

# %% [markdown]
# ![Screenshot_20221213_191019%20%28copia%29.png](attachment:Screenshot_20221213_191019%20%28copia%29.png)

# %% [markdown]
# ✅ The number is 50 (the number is natural):

# %%
print('Please, enter an intenger:')
x = int(input())

while (x < -100 or x > 100):
    x = int(input('Please, enter an intenger: '))

def classifyNumber():
    if x > 0:
        print(f'x = {x}')
        print(f'{x} is a natural number.')
    else:
        print('x = -10')
        
classifyNumber()
# Out:
# Please, enter an intenger:
# 50
# x = 50
# 50 is a natural number.

# %% [markdown]
# ✅ The number is -2 (the number is NOT natural):

# %%
print('Please, enter an intenger:')
x = int(input())

while (x < -100 or x > 100):
    x = int(input('Please, enter an intenger: '))

def classifyNumber():
    if x > 0:
        print(f'x = {x}')
        print(f'{x} is a natural number.')
    else:
        print('x = -10')
        
classifyNumber()
# Out:
# Please, enter an intenger:
# -2
# x = -10

# %% [markdown]
# <font color='blue'>Q1.</font> Programa para clasificar a un usario de acuerdo con su edad

# %% [markdown]
# ![Screenshot_20221214_151001.png](attachment:Screenshot_20221214_151001.png)

# %% [markdown]
# ⚠ Nota: El docente aclaró que un adulto es mayor o igual a 20 años.
#
# ✅ The age is 20 (the user is an adult):

# %%
age = int(input('Please, enter your age: '))

def classifyAge():
    if age >= 20:
        print('Adult.')
    elif 20 > age >= 10:    
        print('Youth.')
    else:
        print('Kid.')
        
classifyAge()
# Out:
# Please, enter your age: 20
# Adult.

# %% [markdown]
# ✅ The age is 10 (the user is youth):

# %%
age = int(input('Please, enter your age: '))

def classifyAge():
    if age >= 20:
        print('Adult.')
    elif 20 > age >= 10:    
        print('Youth.')
    else:
        print('Kid.')
        
classifyAge()
# Out:
# Please, enter your age: 10
# Youth.

# %% [markdown]
# ✅ The age is 9 (the user is a kid):

# %%
age = int(input('Please, enter your age: '))

def classifyAge():
    if age >= 20:
        print('Adult.')
    elif 20 > age >= 10:    
        print('Youth.')
    else:
        print('Kid.')
        
classifyAge()
# Out:
# Please, enter your age: 9
# Kid.

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para clasificar a un usario de acuerdo con su edad y estatura

# %% [markdown]
# ![Screenshot_20221213_191044.png](attachment:Screenshot_20221213_191044.png)

# %% [markdown]
# ⚠ Nota: Se asume que una persona es mayor al cumplir los **18** años.
#
# ✅ The age is 18 and the height is 180 (the user is allow to enter):

# %%
age    = int(input('Please, enter your age: '))
height = int(input('Please, enter your height in cm: '))

def rollerCoaster():
    if age >= 18 and height > 150:
        print('You are available to enter.')
    else:
        print('You are NOT available to enter.')
        
rollerCoaster()
# Out:
# Please, enter your age: 18
# Please, enter your height in cm: 180
# You are available to enter.

# %% [markdown]
# ✅ The age is 18 and the height is 150 (the user is NOT allow to enter):

# %%
age    = int(input('Please, enter your age: '))
height = int(input('Please, enter your height in cm: '))

def rollerCoaster():
    if age >= 18 and height > 150:
        print('You are available to enter.')
    else:
        print('You are NOT available to enter.')
        
rollerCoaster()
# Out:
# Please, enter your age: 18
# Please, enter your height in cm: 150
# You are NOT available to enter.

# %% [markdown]
# <font color='blue'>Q3.</font> Programa para solicitar un tipo de comida en un menú

# %% [markdown]
# ![Screenshot_20221213_191044%20%28copia%29.png](attachment:Screenshot_20221213_191044%20%28copia%29.png)

# %%
def menuMessage():
    print(''.join(('Welcome to yummy restaurant. Here is the menu:\n',
    '- Burger (enter b)\n',
    '- Chicken (enter c)\n',
    '- Pizza (enter p)')))

# %%
def getMenu():
    while True:
        menu = input('Choose a menu (enter b, c, p): ').lower()
        if len(menu) == 1 and menu.isalpha() and menu == 'b' or menu == 'c' or menu =='p':
            return menu
        print('Enter the menu again')

# %%
def restaurant():
    if menu == 'b':
        print('You chose burger.')
    elif menu == 'c':
        print('You chose chicken.')
    else:
        print('You chose pizza.')

# %% [markdown]
# ✅ The food is burger:

# %%
menuMessage()
menu = getMenu()
restaurant()
# Out:
# Welcome to yummy restaurant. Here is the menu:
# - Burger (enter b)
# - Chicken (enter c)
# - Pizza (enter p)
# Choose a menu (enter b, c, p): B
# You chose burger.

# %% [markdown]
# ✅ The food is chicken:

# %%
menuMessage()
menu = getMenu()
restaurant()
# Out:
# Welcome to yummy restaurant. Here is the menu:
# - Burger (enter b)
# - Chicken (enter c)
# - Pizza (enter p)
# Choose a menu (enter b, c, p): C
# You chose chicken.

# %% [markdown]
# ✅ The food is pizza:

# %%
menuMessage()
menu = getMenu()
restaurant()
# Out:
# Welcome to yummy restaurant. Here is the menu:
# - Burger (enter b)
# - Chicken (enter c)
# - Pizza (enter p)
# Choose a menu (enter b, c, p): A
# Enter the menu again
# Choose a menu (enter b, c, p): P
# You chose pizza.

# %% [markdown]
# <hr>
#
# ### Unit 7. Conditional Statements-2: Two-Way Decision Making and Application of Conditional Statements
# Wednesday, December 14, 2022
#
#
# <font color='blue'>Q1.</font> Programa para clasificar a una letra en vocal o consonante

# %% [markdown]
# ![Screenshot_20221214_221255.png](attachment:Screenshot_20221214_221255.png)
#
# ✅ The word is A (The word is a vowel):

# %%
character = input('Please, enter a word: ').lower()

if character in ('a', 'e', 'i', 'o', 'u'):
    print(f'{character.upper()} is a vowel')
else: 
    print(f'{character.upper()} is a consonant')
# Out:
# Please, enter a word: A
# A is a vowel

# %% [markdown]
# ✅ The word is K (The word is a consonant):

# %%
character = input('Please, enter a word: ').lower()

if character in ('a', 'e', 'i', 'o', 'u'):
    print(f'{character.upper()} is a vowel')
else: 
    print(f'{character.upper()} is a consonant')
# Out:
# Please, enter a word: k
# K is a consonant

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para determinar si un número es múltiplo de otro número
# ![Screenshot_20221214_221255%20%28copia%29.png](attachment:Screenshot_20221214_221255%20%28copia%29.png)

# %% [markdown]
# ✅ The dividend is 30 and the divisor is 3 (It is correct):

# %%
dividend, divisor = input('Please, write two intengers: ').split()
dividend = int(dividend)
divisor  = int(divisor)

def multiple(dividend, divisor):
    if dividend % divisor == 0:
        print(f'The number {dividend} is a multiple of the number {divisor}.')
    else: 
        print(f'The number {dividend} is NOT a multiple of the number {divisor}.')

multiple(dividend, divisor)
# Out:
# Please, write two intengers: 30 3
# The number 30 is a multiple of the number 3.

# %% [markdown]
# ✅ The dividend is 13 and the divisor is 2 (It is wrong):

# %%
dividend, divisor = input('Please, write two intengers: ').split()
dividend = int(dividend)
divisor  = int(divisor)

def multiple(dividend, divisor):
    if dividend % divisor == 0:
        print(f'The number {dividend} is a multiple of the number {divisor}.')
    else: 
        print(f'The number {dividend} is NOT a multiple of the number {divisor}.')

multiple(dividend, divisor)
# Out:
# Please, write two intengers: 13 2
# The number 13 is NOT a multiple of the number 2.

# %% [markdown]
# <font color='blue'>Q1.</font> Programa para realizar una operación matemática de acuerdo a dos números
#
# ![Screenshot_20221214_221320.png](attachment:Screenshot_20221214_221320.png)

# %%
def operationMessage():
    print(''.join(('Welcome to calculator. These are the available operations:\n',
    '1) Addition ',
    '2) Subtraction ',
    '3) Multiplication ',
    '4) Division')))

# %%
def getOperation():
    while True:
        operation = int(input('Please, enter the desired number of the operation: '))
        if operation in (1, 2, 3, 4):
            return operation
        print(f'Entered an incorrect number of the operation')

# %%
def getNumbers():
    print('Please, enter two numbers for the operation:')
    n1 = int(input())
    n2 = int(input())
    return n1, n2

# %%
def setOperation():
    if operation == 1:
        print(f'{num1} + {num2} = {num1 + num2}')
    elif operation == 2:
        print(f'{num1} - {num2} = {num1 - num2}')
    elif operation == 3:
        print(f'{num1} * {num2} = {num1 * num2}')
    else:
        print(f'{num1} / {num2} = {num1 / num2}') if num2 != 0 else print('Error. Division by 0.')

# %% [markdown]
# ✅ Addition

# %%
operationMessage()
operation  = getOperation()
num1, num2 = getNumbers()
setOperation()
# Out:
# Welcome to calculator. These are the available operations:
# 1) Addition 2) Subtraction 3) Multiplication 4) Division
# Please, enter the desired number of the operation: 1
# Please, enter two numbers for the operation:
# 10
# 20
# 10 + 20 = 30

# %% [markdown]
# ✅ Substraction

# %%
operationMessage()
operation  = getOperation()
num1, num2 = getNumbers()
setOperation()
# Out:
# Welcome to calculator. These are the available operations:
# 1) Addition 2) Subtraction 3) Multiplication 4) Division
# Please, enter the desired number of the operation: 2
# Please, enter two numbers for the operation:
# 6
# 3
# 6 - 3 = 3

# %% [markdown]
# ✅ Multiplication

# %%
operationMessage()
operation  = getOperation()
num1, num2 = getNumbers()
setOperation()
# Out:
# Welcome to calculator. These are the available operations:
# 1) Addition 2) Subtraction 3) Multiplication 4) Division
# Please, enter the desired number of the operation: 3
# Please, enter two numbers for the operation:
# 120
# 5
# 120 * 5 = 600

# %% [markdown]
# ✅ Division

# %%
operationMessage()
operation  = getOperation()
num1, num2 = getNumbers()
setOperation()
# Out:
# Welcome to calculator. These are the available operations:
# 1) Addition 2) Subtraction 3) Multiplication 4) Division
# Please, enter the desired number of the operation: 4
# Please, enter two numbers for the operation:
# 40
# 2
# 40 / 2 = 20.0

# %% [markdown]
# ✅ Division by 0 and wrong operation

# %%
operationMessage()
operation  = getOperation()
num1, num2 = getNumbers()
setOperation()
# Out:
# Welcome to calculator. These are the available operations:
# 1) Addition 2) Subtraction 3) Multiplication 4) Division
# Please, enter the desired number of the operation: 7
# Entered an incorrect number of the operation
# Please, enter the desired number of the operation: 4
# Please, enter two numbers for the operation:
# 4
# 0
# Error. Division by 0.

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para clasificar dos números en un cuadrante
#
# ![Screenshot_20221214_221324.png](attachment:Screenshot_20221214_221324.png)

# %%
def getCoordinates():
    return input('Please, type two intengers: ').split()

# %%
def verifyQuadrant():
    if x > 0 and y > 0:
        print(f'Your coordinates ({x}, {y}) correspond to the first quadrant.')
    elif x < 0 and y > 0:
        print(f'Your coordinates ({x}, {y}) correspond to the second quadrant.')
    elif x < 0 and y < 0:
        print(f'Your coordinates ({x}, {y}) correspond to the third quadrant.')
    else:
        print(f'Your coordinates ({x}, {y}) correspond to the fourth quadrant.')

# %% [markdown]
# ✅ X is 5 and Y is 6 (First quadrant)

# %%
x, y = getCoordinates()

x = int(x)
y = int(y)

verifyQuadrant()
# Out:
# Please, type two intengers: 5 6
# Your coordinates (5, 6) correspond to the first quadrant.

# %% [markdown]
# ✅ X is -5 and Y is 6 (Second quadrant)

# %%
x, y = getCoordinates()

x = int(x)
y = int(y)

verifyQuadrant()
# Out:
# Please, type two intengers: -5 6
# Your coordinates (-5, 6) correspond to the second quadrant.

# %% [markdown]
# ✅ X is -5 and Y is -6 (Third quadrant)

# %%
x, y = getCoordinates()

x = int(x)
y = int(y)

verifyQuadrant()
# Out:
# Please, type two intengers: -5 -6
# Your coordinates (-5, -6) correspond to the third quadrant.

# %% [markdown]
# ✅ X is 5 and Y is -6 (Second quadrant)

# %%
x, y = getCoordinates()

x = int(x)
y = int(y)

verifyQuadrant()
# Out:
# Please, type two intengers: 5 -6
# Your coordinates (5, -6) correspond to the fourth quadrant.

# %% [markdown]
# <font color='blue'>Q3.</font> Programa para solicitar un tipo de comida en un menú
#
# ![Screenshot_20221214_221327.png](attachment:Screenshot_20221214_221327.png)
#
# ⚠ Nota: El ejercicio se encuentra duplicado, ya se desarrolló en la anterior unidad.

# %%
def menuMessage():
    print(''.join(('Welcome to yummy restaurant. Here is the menu:\n',
    '- Burger (enter b)\n',
    '- Chicken (enter c)\n',
    '- Pizza (enter p)')))

# %%
def getMenu():
    while True:
        menu = input('Choose a menu (enter b, c, p): ').lower()
        if len(menu) == 1 and menu.isalpha() and menu == 'b' or menu == 'c' or menu =='p':
            return menu
        print('Enter the menu again')

# %%
def restaurant():
    if menu == 'b':
        print('You chose burger.')
    elif menu == 'c':
        print('You chose chicken.')
    else:
        print('You chose pizza.')

# %%
menuMessage()
menu = getMenu()
restaurant()
# Out:
# Welcome to yummy restaurant. Here is the menu:
# - Burger (enter b)
# - Chicken (enter c)
# - Pizza (enter p)
# Choose a menu (enter b, c, p): P
# You chose pizza.

# %% [markdown]
# <hr>
#
# ### Unit 8. loop-1
# Thursday, December 15, 2022
#
#
# <font color='blue'>Q1.</font> Programa para imprimir los elementos de una lista
#
# ![Screenshot_20221215_010130.png](attachment:Screenshot_20221215_010130.png)

# %%
bts = ['V', 'J-Hope', 'RM', 'Jungkook', 'Jin', 'Jimin', 'Suga']

def btsMembers():
    for person in bts:
        print(person)
btsMembers()
# Out:
# V
# J-Hope
# RM
# Jungkook
# Jin
# Jimin
# Suga

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para imprimir los elementos de una lista
#
# ![Screenshot_20221215_010137.png](attachment:Screenshot_20221215_010137.png)

# %%
counter = 0
minimum = 1
maximum = 101

def sum(counter, minimum, maximum):
    for number in range(minimum, maximum):
        counter += number
    print(f'Sum of integers from {minimum} to {maximum - 1}: {counter}')
        
sum(counter, minimum, maximum)
# Out:
# Sum of integers from 1 to 100: 5050

# %% [markdown]
# <font color='blue'>Q3.</font> Programa para imprimir los elementos de una lista
#
# ![Screenshot_20221215_010137%20%28copia%29.png](attachment:Screenshot_20221215_010137%20%28copia%29.png)

# %%
counter = 0
minimum = 1
maximum = 101

def sum(counter, minimum, maximum):
    for number in range(minimum, maximum):
        if number % 2 == 0:
            counter += number
    print(f'Sum of even numbers from {minimum} to {maximum - 1}: {counter}')
        
sum(counter, minimum, maximum)
# Out:
# Sum of even numbers from 1 to 100: 2550

# %% [markdown]
# <font color='blue'>Q4.</font> Programa para imprimir los elementos de una lista
#
# ![Screenshot_20221215_010146.png](attachment:Screenshot_20221215_010146.png)

# %%
counter = 0
minimum = 1
maximum = 101

def sum(counter, minimum, maximum):
    for number in range(minimum, maximum):
        if number % 2 != 0:
            counter += number
    print(f'Sum of odd numbers from {minimum} to {maximum - 1}: {counter}')
        
sum(counter, minimum, maximum)
# Out:
# Sum of odd numbers from 1 to 100: 2500

# %% [markdown]
# <font color='blue'>Q1.</font> Programa para mostrar la cantidad de sillas de una sala de conciertos
#
# ![Screenshot_20221215_010208.png](attachment:Screenshot_20221215_010208.png)

# %% [markdown]
# ✅ Seat is 5 (The total seats are 25).

# %%
def seatMessage():
    return int(input('Please, select your seat number: '))

# %%
def initializeMatrix():
    return [[0 for _ in range(seat)] for _ in range(seat)]

# %%
def buildMatrix():
    counter = 0
    for row in range(seat):
        if row % 2 == 0:
            for col in range(seat):
                counter += 1
                matrix[row][col] = counter
        else:
            for col in range(seat - 1, -1, -1):
                counter += 1
                matrix[row][col] = counter

# %%
def showMatrix():
    for row in range(seat):
        for col in range(seat):
            print(str(matrix[row][col]).rjust(4), end='')
        print()

# %%
seat   = seatMessage()
matrix = initializeMatrix()
buildMatrix()
showMatrix()
# Out:
# Please, select your seat number: 5
#    1   2   3   4   5
#   10   9   8   7   6
#   11  12  13  14  15
#   20  19  18  17  16
#   21  22  23  24  25

# %% [markdown]
# ✅ Seat is 5 (The total seats are 25). Using reverse python function. The **reverse()** method reverses the elements of the list.

# %%
def seatMessage():
    return int(input('Please, select your seat number: '))

# %%
def showMatrix():
    for row in range (1, seat + 1):
        l = [(row - 1) * seat + col for col in range(1, seat + 1)]
        if row % 2 == 0: l.reverse()
        for col in l: print(str(col).rjust(4), end='')
        print()

# %%
seat = seatMessage()
showMatrix()
# Out:
# Please, select your seat number: 5
#    1   2   3   4   5
#   10   9   8   7   6
#   11  12  13  14  15
#   20  19  18  17  16
#   21  22  23  24  25

# %% [markdown]
# <hr>
#
# ### Unit 8. loop-2
# Friday, December 16, 2022
#
#
# <font color='blue'>Q1.</font> Programa para imprimir la multiplicación del número 2
#
# ![Screenshot_20221215_012620.png](attachment:Screenshot_20221215_012620.png)

# %%
base     = 2
exponent = 1
maximum  = 9

while(exponent <= maximum):
    print(f'{base} * {exponent} = {base * exponent}')
    exponent += 1
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para imprimir la multiplicación de un número hasta el 9
#
# ![Screenshot_20221215_012624.png](attachment:Screenshot_20221215_012624.png)

# %%
base    = 1
maximum = 9

def multiplication(maximum, base):
    exponent = 1
    while(exponent <= maximum):
        print(f'{base} * {exponent} = {base * exponent}')
        exponent += 1
    if(base < maximum): multiplication(maximum, base = base + 1)

multiplication(maximum, base)
# Out:
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# ...

# %% [markdown]
# <font color='blue'>Q1.</font> Programa para determinar si un número es palíndromo
#
# ![Screenshot_20221215_012635.png](attachment:Screenshot_20221215_012635.png)
#
# ✅ Seat is 3443 (It is a palindrome). Using reverse python function.

# %%
def palindromeMessage():
    return int(input('Please, enter an intenger: '))

# %%
def verifyPalindrome():
    palindrome = ''.join(reversed(number))
    if palindrome == number: 
        print(f'{int(number)} is a palindrome number.')
    else:
        print(f'{int(number)} is NOT a palindrome number.')

# %%
number = str(palindromeMessage())
verifyPalindrome()
# Out:
# Please, enter an intenger: 3443
# 3443 is a palindrome number.

# %% [markdown]
# ✅ Seat is 135 (It is NOT a palindrome).

# %%
def palindromeMessage():
    return int(input('Please, enter an intenger: '))

# %%
def verifyPalindrome():
    palindrome = number[::-1]
    if palindrome == number: 
        print(f'{int(number)} is a palindrome number.')
    else:
        print(f'{int(number)} is NOT a palindrome number.')

# %%
number = str(palindromeMessage())
verifyPalindrome()
# Out:
# Please, enter an intenger: 135
# 135 is NOT a palindrome number.

# %% [markdown]
# <font color='blue'>Q2.</font> Programa para adivinar un número dentro de un rango
#
# ![Screenshot_20221215_012635%20%28copia%29.png](attachment:Screenshot_20221215_012635%20%28copia%29.png)

# %% [markdown]
# ✅ Number is 88.

# %%
import random
number = random.randint(1, 100)
print(number)
# Out:
# 88

# %%
def guessNumber():
    counter = 0
    while True:
        counter += 1
        userN = int(input('Please, enter an intenger: '))
        if userN == number:
            print(f'Congratulations. You guessed the number: {number} in {counter} tries.')
            break
        elif userN >= number:
            print('Lower!')
        else:
            print('Higher!')

# %%
guessNumber()
# Out:
# Please, enter an intenger: 92
# Lower!
# Please, enter an intenger: 84
# Higher!
# Please, enter an intenger: 89
# Lower!
# Please, enter an intenger: 88
# Congratulations. You guessed the number: 88 in 4 tries.
